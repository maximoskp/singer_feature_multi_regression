# %%
from pathlib import Path
import posixpath
import pandas as pd

# %%
csv_path = '/media/maximos/9C33-6BBD/data/melos_singers/features/merged_df_PCA.csv'

# %%
feats = pd.read_csv(csv_path, delimiter=',')

# %%
n = feats['names'].str.split('_').str[0]
# add names as new column
feats.insert(1, 'name_class', n, True)
# assign class number
feats.insert(2, 'singer_id', feats.groupby('name_class').ngroup(), True)

# %%
feats.head()
# Out:
#         names name_class  singer_id       Pitch  SpectralCentroid  \
# 0  bellou_a_1     bellou          0  294.792756       1988.705488
# 1  bellou_a_2     bellou          0  224.575582       1191.358861
# 2  bellou_a_3     bellou          0  215.427334       1630.110589
# 3  bellou_a_4     bellou          0  310.702620       1215.894880
# 4  bellou_a_5     bellou          0  326.715388       1111.645409
#
#    SpectralSpread  SpectralSkewness  SpectralKurtosis  SpectralFlatness  \
# 0     1236.076582          0.667607          2.230896      6.130028e-05
# 1      663.951795          1.619319          6.378916      1.482950e-09
# 2     1201.959572          1.233063          3.561876      3.840608e-04
# 3      740.676596          1.352175          4.917070      1.353494e-03
# 4      576.713488          1.669873          6.963033      4.287648e-09
#
#    SpectralCrest  ...       F1_Hz        F2_Hz        F3_HZ        F4_Hz  \
# ...

# %%
# drop unnecessary labels for multitask
feats.drop(['name_class', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
feats.head()
# Out:
#         names  singer_id       Pitch  SpectralCentroid  SpectralSpread  \
# 0  bellou_a_1          0  294.792756       1988.705488     1236.076582
# 1  bellou_a_2          0  224.575582       1191.358861      663.951795
# 2  bellou_a_3          0  215.427334       1630.110589     1201.959572
# 3  bellou_a_4          0  310.702620       1215.894880      740.676596
# 4  bellou_a_5          0  326.715388       1111.645409      576.713488
#
#    SpectralSkewness  SpectralKurtosis  SpectralFlatness  SpectralCrest  \
# 0          0.667607          2.230896      6.130028e-05       0.166799
# 1          1.619319          6.378916      1.482950e-09       0.309095
# 2          1.233063          3.561876      3.840608e-04       0.198526
# 3          1.352175          4.917070      1.353494e-03       0.247989
# 4          1.669873          6.963033      4.287648e-09       0.394933
#
#    SpectralSlope  ...  Noisiness  HarmonicToNoiseEnergy  \
# ...

# %%
new_csv_path = '/media/maximos/9C33-6BBD/data/melos_singers/features/multitask_targets.csv'

# %%
feats.to_csv( new_csv_path )

# %%
print(list(feats.columns))
# Out:
# ['names', 'singer_id', 'Pitch', 'SpectralCentroid', 'SpectralSpread', 'SpectralSkewness', 'SpectralKurtosis', 'SpectralFlatness', 'SpectralCrest', 'SpectralSlope', 'SpectralDecrease', 'SpectralRollOff', 'SpectralVariation', 'SpectralFlux', 'HarmonicSpectralDeviation', 'Tristimulus_1', 'Tristimulus_2', 'Tristimulus_3', 'HarmonicOddToEvenRatio', 'Inharmonicity', 'HarmonicEnergy', 'NoiseEnergy', 'Noisiness', 'HarmonicToNoiseEnergy', 'PartialsToNoiseEnergy', 'F1_Hz', 'F2_Hz', 'F3_HZ', 'F4_Hz', 'Rate', 'Depth', 'Regularity']
